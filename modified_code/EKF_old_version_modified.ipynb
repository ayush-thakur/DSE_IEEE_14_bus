# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot



Pi= pd.read_csv("../data/PQ_fault_modified2.csv")
df=pd.read_csv("../data/Vrms_fault2.csv")

nbus=14;
Pi= Pi.to_numpy();

Pi=Pi;




# Define the function to calculate the state transition matrix F
# def calculate_state_transition_matrix():
    
#     F = np.zeros((num_buses * num_state_variables, num_buses * num_state_variables))
    
#     # Calculate F using the linearized power flow equations
#     for i in range(num_buses):
#         for j in range(num_buses):
#             if i != j:
#                 # Partial derivatives of P_i w.r.t. V_i, θ_i
#                 F[i][i] += V[j] * (G[i,j] * np.cos(del1[i] - del1[j]) + B[i,j] * np.sin(del1[i] - del1[j]))
#                 F[i][j] += V[i] * (G[i,j] * np.cos(del1[i] - del1[j]) + B[i,j] * np.sin(del1[i] - del1[j]))
#                 F[i + num_buses][i] += -V[i] * (G[i,j] * np.sin(del1[i] - del1[j]) - B[i,j] * np.cos(del1[i] - del1[j]))
#                 F[i + num_buses][j] += -V[i] * (G[i,j]* np.sin(de1l[i] - del1[j]) - B[i,j] * np.cos(del1[i] - del1[j]))

#                 # Partial derivatives of Q_i w.r.t. V_i, θ_i
#                 F[i + num_buses * num_buses][i] += V[j] * (G[i,j] * np.sin(del1[i] - del1[j]) - B[i,j] * np.cos(del1[i] - del1[j]))
#                 F[i + num_buses * num_buses][j] += V[i] * (G[i,j] * np.sin(del1[i] - del1[j]) - B[i,j] * np.cos(del1[i] - del1[j]))
#                 F[i + num_buses * num_buses * 2][i] += V[i] * (G[i,j] * np.cos(del1[i] - del1[j]) + B[i,j] * np.sin(del1[i] - del1[j]))
#                 F[i + num_buses * num_buses * 2][j] += V[i] * (G[i,j] * np.cos(del1[i] - del1[j]) + B[i,j] * np.sin(del1[i] - del1[j]))

#     return F


def bbusppg(num):     # Returns B-bus..

    linedata = linedatas(num);
    fb = linedata[:,0];  #first column 
    tb = linedata[:,1];  #2nd column 
    b = linedata[:,4];   #5th column
    nbus = int(np.max([np.max(fb),np.max(tb)]))    # no. of buses...
    nbranch = len(fb);           # no. of branches...
    bbus = np.mat(np.zeros((nbus,nbus)));

    for k in range (0,nbranch):
        bbus[int(fb[k]-1),int(tb[k]-1)] = b[k]
        bbus[int(tb[k]-1),int(fb[k]-1)] = bbus[int(fb[k]-1),int(tb[k]-1)];

    return bbus
# Traditional Measurement Data..
# Vi - 1, Pi - 2, Qi - 3, Pij - 4, Qij - 5, Iij - 6],

def zdatas(i):

        #      |Msnt |Type | Value | From | To | Rii | 
        #---- Voltage Magnitude ------------#
        
    v1= df[f'Subsystem #1|CTLs|Vars|Vrms_1'][i]/11    
    Pow_i= Pi[i];  

    zdata14   =  np.mat([[1 , 1  ,  v1 , 1 ,   0 ,  9e-4],
             #-----------------------------------#
             #---- Real Power Injection ---------#
             [2 , 2  ,  Pow_i[1] ,  2 ,   0 ,  1e-4],
             [3 , 2 ,  Pow_i[2] ,  3 ,   0 ,  1e-4], 
             [4 , 2 ,  Pow_i[3] , 7 ,   0  , 1e-4],
             [5 , 2 ,  Pow_i[4]   , 8 ,   0  , 1e-4], 
             [6 , 2 ,  Pow_i[5] , 10 ,   0 ,  1e-4],
             [7 , 2 ,  Pow_i[6] , 11 ,   0 ,  1e-4],
             [8 , 2 ,  Pow_i[7], 12 ,   0 ,  1e-4], 
             [9 , 2 ,  Pow_i[8] , 14 ,   0 ,  1e-4],
             #------------------------------------#
             #---- Reative Power Injection -------#
             [10 , 3 ,   Pow_i[9] ,  2 ,   0 ,  1e-4],
             [11 , 3 ,   Pow_i[10] ,  3 ,   0 ,  1e-4], 
             [12 , 3 ,   Pow_i[11] , 7 ,   0  , 1e-4],
             [13 , 3 ,   Pow_i[12],  8 ,   0 ,  1e-4], 
             [14 , 3 ,  Pow_i[13] , 10 ,   0 ,  1e-4],
             [15 , 3 ,  Pow_i[14], 11 ,   0 ,  1e-4],
             [16 , 3 ,  Pow_i[15], 12 ,   0 ,  1e-4], 
             [17 , 3 ,  Pow_i[16], 14 ,   0 ,  1e-4],
             #------------------------------------#
             #------ Real Power Flow ------------- #
             [18 , 4 ,   Pow_i[17] ,  1 ,   2 ,  64e-6],
             [19 , 4 ,   Pow_i[18],  2 ,   3 ,  64e-6],
             [20 , 4 ,  Pow_i[19] ,  4 ,   2 ,  64e-6],
             [21 , 4 ,   Pow_i[20] ,  4 ,   7 ,  64e-6],
             [22 , 4 ,   Pow_i[21] ,  4 ,   9 ,  64e-6],
             [23 , 4 ,  Pow_i[22] ,  5 ,   2 ,  64e-6],
             [24 , 4 ,   Pow_i[23],  5 ,   4 ,  64e-6],
             [25 , 4 ,   Pow_i[24],  5 ,   6 ,  64e-6],
             [26 , 4 ,   Pow_i[25] ,  6 ,  13 ,  64e-6],
             [27 , 4 ,   Pow_i[26] ,  7 ,   9 ,  64e-6],
             [28 , 4 ,  Pow_i[27] , 11 ,   6 ,  64e-6],
             [29 , 4 ,  Pow_i[28] , 12 ,  13 ,  64e-6],
             #------------------------------------#
             #------ Reactive Power Flow -------- #
             [30 , 5 ,  Pow_i[29] ,  1 ,   2 ,  64e-6],
             [31 , 5 ,  Pow_i[30] ,  2 ,   3 ,  64e-6],
             [32 , 5 ,  Pow_i[31] ,  4 ,   2 ,  64e-6],
             [33 , 5 ,  Pow_i[32] ,  4 ,   7 ,  64e-6],
             [34 , 5 ,  Pow_i[33] ,  4 ,  9 ,  64e-6],
             [35 , 5 ,  Pow_i[34] ,  5 ,   2 ,  64e-6],
             [36 , 5 ,  Pow_i[35] ,  5 ,   4 ,  64e-6],
             [37 , 5 ,  Pow_i[36] ,  5 ,   6 ,  64e-6],
             [38 , 5 ,  Pow_i[37] ,  6 ,  13 ,  64e-6],
             [39 , 5 ,  Pow_i[38] ,  7 ,   9 ,  64e-6],
             [40 , 5 ,  Pow_i[39] , 11 ,   6 ,  64e-6],
             [41 , 5 ,  Pow_i[40] , 12 ,  13 ,  64e-6]]);
             #--------------------------------------#


    # Just in case you want to add other systems, add the data above 
    # and change the following condition accordingly
    if num == 3:
        zdt =zdata3;
    elif num==14:
        zdt = zdata14;
    elif num==30:
        zdt = zdata30
        
             
    return zdt
# Line data function

def  linedatas(num):

    # ,    |  From |  To   |   R     |   X     |     B/2  |  X'mer  |
    # ,    |  Bus  | Bus   |  pu     |  pu     |     pu   | TAP (a) |
    linedat14 = np.mat([[1 ,   2 ,  0.01938  , 0.05917  ,  0.0264 ,    1],
                       [1 ,    5 ,  0.05403  , 0.22304  ,  0.0246 ,    1],
                       [2 ,    3 ,  0.04699  , 0.19797  ,  0.0219 ,    1],
                       [2 ,    4 ,  0.05811  , 0.17632  ,  0.0170 ,    1],
                       [2 ,    5 ,  0.05695  , 0.17388  ,  0.0173 ,    1],
                       [3 ,    4 ,  0.06701  , 0.17103  ,  0.0064 ,    1],
                       [4 ,    5 ,  0.01335  , 0.04211  ,  0.0    ,    1],
                       [4 ,    7 ,  0.0      , 0.20912  ,  0.0 ,   0.978],
                       [4 ,    9 ,  0.0      , 0.55618  ,  0.0 ,   0.969],
                       [5 ,    6 ,  0.0      , 0.25202  ,  0.0 ,   0.932],
                       [6 ,    11,  0.09498  , 0.19890  ,  0.0 ,       1],
                       [6 ,    12,  0.12291  , 0.25581  ,  0.0 ,       1],
                       [6 ,    13,  0.06615  , 0.13027  ,  0.0 ,       1],
                       [7 ,    8 ,  0.0      , 0.17615  ,  0.0 ,       1],
                       [7 ,    9 ,  0.0      , 0.11001  ,  0.0 ,       1],
                       [9 ,    10,  0.03181  , 0.08450  ,  0.0 ,       1],
                       [9 ,    14,  0.12711  , 0.27038  ,  0.0 ,       1],
                       [10 ,   11,  0.08205  , 0.19207  ,  0.0 ,       1],
                       [12 ,   13,  0.22092  , 0.19988  ,  0.0 ,       1],
                       [13 ,   14,  0.17093  , 0.34802  ,  0.0 ,       1]]);


    if num == 3:
        linedt = linedat3;
    elif num==14: 
        linedt = linedat14;
    elif num==30:
        linedt = linedat30;
        
             
    return linedt
# Returns ybus
def ybusppg(num):  

    linedata = linedatas(num); # Calling "linedata6.m" for Line Data...
    fb = linedata[:,0];     # From bus number...
    tb = linedata[:,1];     # To bus number...
    r = linedata[:,2];      # Resistance, R...
    x = linedata[:,3];      # Reactance, X...
    b = linedata[:,4];      # Ground Admittance, B/2...
    a = linedata[:,5];      # Tap setting value..
    z = r + x*1j;            # Z matrix...
    y = 1/z;               # To get inverse of each element...
    b = b*1j;                # Make B imaginary...

    nbus = int(np.max([np.max(fb),np.max(tb)]));    # no. of buses...
    nbranch = len(fb) # no. of branches...(= 20)
    ybus = np.mat(np.zeros((nbus,nbus), dtype=complex));       # Initialise YBus...
    
    # Formation of the Off Diagonal Elements...
    for k in range (0,nbranch):
        ybus[int(fb[k]-1),int(tb[k]-1)] =ybus[int(fb[k]-1),int(tb[k]-1)]- (y[k]/a[k]);
        ybus[int(tb[k]-1),int(fb[k]-1)] = ybus[int(fb[k]-1),int(tb[k]-1)];
 
 
    # Formation of Diagonal Elements....
    for m in range (0,nbus):
        for n in range (0,nbranch):
            if fb[n]-1 == m:
                ybus[m,m]=ybus[m,m]+ (y[n]/(a[n]**2)) + b[n]
            elif tb[n]-1 ==m:
                ybus[m,m]=ybus[m,m]+y[n]
                

    return ybus
# The main code for state estimation using WLS


Y_V= [0]*14;
Y_D= [0]*14;
V = np.ones((nbus,1)) # Initialize the bus voltages..
del1 = np.zeros((nbus,1)); # Initialize the bus angles..
E_in = np.matrix(np.concatenate((del1, V)))
P= np.eye(2*14-1)*1e-4
Q=np.eye(27)*6*1e-1
iter = 1;
tol = 5;
R= np.eye(41)*5*1e-3
x_g=[]
y_g=[]
y_error=[]

y_actual=[]
y_per_error=[]
c1=0

for i2 in range(14):
    y_g.append([])
    y_error.append([])
    y_actual.append([])
    y_per_error.append([])


for x in range (800,1500):
    num=14;
    del_T=0.001;
    ybus = ybusppg(num); # Get YBus..
    zdata = zdatas(x); # Get Measurement data..
    
    #in every iteration we take a new row to consider from the csv file we imported
    
    bpq = bbusppg(num); # Get B data..
    nbus = int(np.max([np.max(zdata[:,3]),np.max(zdata[:,4])])); # Get number of buses..
    type1 = zdata[:,1]; # Type of measurement, Vi - 1, Pi - 2, Qi - 3, Pij - 4, Qij - 5, Iij - 6..
    z = zdata[:,2]; # Measuement values..
    fbus = zdata[:,3]; # From bus..
    tbus = zdata[:,4]; # To bus..
    Ri = np.diagflat(zdata[:,5]) # Measurement Error..
   
    G = ybus.real;
    B = ybus.imag 
    E = np.matrix(np.concatenate((del1[1:], V)))

    vi = np.mat((type1 == 1).nonzero())[0,:]; # Index of measurements..
    ppi = np.mat((type1 == 2).nonzero())[0,:];
    qi = np.mat((type1 == 3).nonzero())[0,:]
    pf = np.mat((type1 == 4).nonzero())[0,:]
    qf = np.mat((type1 == 5).nonzero())[0,:]

    nvi = vi.shape[1]; # Number of Voltage measurements..
    npi = ppi.shape[1]; # Number of Real Power Injection measurements..
    nqi = qi.shape[1]; # Number of Reactive Power Injection measurements..
    npf = pf.shape[1]; # Number of Real Power Flow measurements..
    nqf = qf.shape[1]; # Number of Reactive Power Flow measurements..

    h1 = np.mat(V[int(fbus[vi])-1,0]);
    h2 = np.mat(np.zeros((npi,1)));
    h3 = np.mat(np.zeros((nqi,1)));
    h4 = np.mat(np.zeros((npf,1)));
    h5 = np.mat(np.zeros(((nqf,1))));
    

    for i in range(0,npi):
        m = int(fbus[(ppi[0,i])])-1
        for k in range(0,nbus):
            h2[i] += V[m]*V[k]*(G[m,k]*np.cos(del1[m]-del1[k]) + B[m,k]*np.sin(del1[m]-del1[k]))

    for i in range(0,nqi):
        m = int(fbus[(qi[0,i])])-1
        for k in range(0,nbus):
            h3[i] += V[m]*V[k]*((G[m,k]*np.sin(del1[m]-del1[k])) - (B[m,k]*np.cos(del1[m]-del1[k])))

    for i in range(0,npf):
        m = int(fbus[(pf[0,i])])-1
        n = int(tbus[(pf[0,i])])-1
        h4[i] = -(V[m]**2)*G[m,n] - V[m]*V[n]*(-G[m,n]*np.cos(del1[m]-del1[n]) - B[m,n]*np.sin(del1[m]-del1[n]))

    for i in range(0,nqf):
        m = int(fbus[(qf[0,i])])-1
        n = int(tbus[(qf[0,i])])-1
        h5[i] = -(V[m]**2)*(-B[m,n]+bpq[m,n]) - V[m]*V[n]*(-G[m,n]*np.sin(del1[m]-del1[n]) + B[m,n]*np.cos(del1[m]-del1[n]))

    h=np.mat(np.concatenate((h1,h2,h3,h4,h5)))

        # residual
    r = z - h

        # Jacobian
    H11=np.mat(np.zeros((nvi,nbus-1)))

    H12=np.mat(np.zeros((nvi,nbus)))
    for k in range(0,nvi):
        for n in range(0,nvi):
            if n == k:
                 H12[k,n]=1

    H21=np.mat(np.zeros((npi,nbus-1)))
    for i in range(0,npi):
        m = int(fbus[(ppi[0,i])])-1
        for k in range(0,nbus-1):
            if k+1 == m:
                for n in range(0,nbus):
                    H21[i,k] += V[m]*V[n]*(-G[m,n]*np.sin(del1[m]-del1[n]) + B[m,n]*np.cos(del1[m]-del1[n]))
                H21[i,k] -= (V[m]**2)*B[m,m]
            else:
                H21[i,k]=V[m]*V[k+1]*(G[m,k+1]*np.sin(del1[m]-del1[k+1]) - B[m,k+1]*np.cos(del1[m]-del1[k+1]))

    H22=np.mat(np.zeros((npi,nbus)))
    for i in range(0,npi):
        m = int(fbus[(ppi[0,i])])-1
        for k in range(0,nbus):
            if k == m:
                for n in range(0,nbus):
                    H22[i,k] += V[n]*(G[m,n]*np.cos(del1[m]-del1[n]) + B[m,n]*np.sin(del1[m]-del1[n]))
                H22[i,k] += V[m]*G[m,m]
            else:
                H22[i,k]=V[m]*(G[m,k]*np.cos(del1[m]-del1[k]) + B[m,k]*np.sin(del1[m]-del1[k]))

    H31=np.mat(np.zeros((nqi,nbus-1)))
    for i in range(0,nqi):
        m = int(fbus[(qi[0,i])])-1
        for k in range(0,nbus-1):
            if k+1 == m:
                for n in range(0,nbus):
                     H31[i,k] += V[m]*V[n]*(G[m,n]*np.cos(del1[m]-del1[n]) + B[m,n]*np.sin(del1[m]-del1[n]))
                H31[i,k] -= (V[m]**2)*G[m,m]
            else:
                H31[i,k]=V[m]*V[k+1]*(-G[m,k+1]*np.cos(del1[m]-del1[k+1]) - B[m,k+1]*np.sin(del1[m]-del1[k+1]))

    H32=np.mat(np.zeros((nqi,nbus)))
    for i in range(0,nqi):
        m = int(fbus[(qi[0,i])])-1
        for k in range(0,nbus):
            if k == m:
                for n in range(0,nbus):
                     H32[i,k] += V[n]*(G[m,n]*np.sin(del1[m]-del1[n]) - B[m,n]*np.cos(del1[m]-del1[n]))
                H32[i,k] -= V[m]*B[m,m]
            else:
                H32[i,k]=V[m]*(G[m,k]*np.sin(del1[m]-del1[k]) - B[m,k]*np.cos(del1[m]-del1[k]))

    H41=np.mat(np.zeros((npf,nbus-1)))
    for i in range(0,npf):
        m = int(fbus[(pf[0,i])])-1
        n = int(tbus[(pf[0,i])])-1
        for k in range(0,nbus-1):
            if k+1 == m:
                H41[i,k] = V[m]*V[n]*(-G[m,n]*np.sin(del1[m]-del1[n]) + B[m,n]*np.cos(del1[m]-del1[n]))
            elif k+1 == n:
                H41[i,k] = -V[m]*V[n]*(-G[m,n]*np.sin(del1[m]-del1[n]) + B[m,n]*np.cos(del1[m]-del1[n]))
            else:
                H41[i,k] = 0

    H42=np.mat(np.zeros((npf,nbus)))
    for i in range(0,npf):
        m = int(fbus[(pf[0,i])])-1
        n = int(tbus[(pf[0,i])])-1
        for k in range(0,nbus):
            if k == m:
                H42[i,k] = -V[n]*(-G[m,n]*np.cos(del1[m]-del1[n]) - B[m,n]*np.sin(del1[m]-del1[n])) -2*G[m,n]*V[m]
            elif k == n:
                H42[i,k] = -V[m]*(-G[m,n]*np.cos(del1[m]-del1[n]) - B[m,n]*np.sin(del1[m]-del1[n]))
            else:
                H42[i,k] = 0

    H51=np.mat(np.zeros((nqf,nbus-1)))
    for i in range(0,nqf):
        m = int(fbus[(qf[0,i])])-1
        n = int(tbus[(qf[0,i])])-1
        for k in range(0,nbus-1):
            if k+1 == m:
                 H51[i,k] = -V[m]*V[n]*(-G[m,n]*np.cos(del1[m]-del1[n]) - B[m,n]*np.sin(del1[m]-del1[n]))
            elif k+1 == n:
                H51[i,k] = V[m]*V[n]*(-G[m,n]*np.cos(del1[m]-del1[n]) - B[m,n]*np.sin(del1[m]-del1[n]))
            else:
                H51[i,k] = 0

    H52=np.mat(np.zeros((nqf,nbus)))
    for i in range(0,nqf):
        m = int(fbus[(qf[0,i])])-1
        n = int(tbus[(qf[0,i])])-1
        for k in range(0,nbus):
            if k == m:
                H52[i,k] = -V[n]*(-G[m,n]*np.sin(del1[m]-del1[n]) + B[m,n]*np.cos(del1[m]-del1[n])) -2*V[m]*(-B[m,n]+bpq[m,n])
            elif k == n:
                H52[i,k] = -V[m]*(-G[m,n]*np.sin(del1[m]-del1[n]) + B[m,n]*np.cos(del1[m]-del1[n]))
            else:
                H52[i,k] = 0

    H1=np.mat(np.concatenate((H11,H12),axis=1))
    H2=np.mat(np.concatenate((H21,H22),axis=1))
    H3=np.mat(np.concatenate((H31,H32),axis=1))
    H4=np.mat(np.concatenate((H41,H42),axis=1))
    H5=np.mat(np.concatenate((H51,H52),axis=1))

    H=np.mat(np.concatenate((H1,H2,H3,H4,H5)))
    num_buses=14;
    F = np.zeros((num_buses * 2-1, num_buses * 2-1))
    
    # Calculate F using the linearized power flow equations
    for i in range(0,num_buses-1):
        for j in range(0,num_buses-1):
            if i != j:
                # Partial derivatives of P_i w.r.t. V_i, θ_i
                F[i][i] += V[j] * (G[i,j] * np.cos(del1[i] - del1[j]) + B[i,j] * np.sin(del1[i] - del1[j]))
                F[i][j] += V[i] * (G[i,j] * np.cos(del1[i] - del1[j]) + B[i,j] * np.sin(del1[i] - del1[j]))
                F[i + num_buses][i] += -V[i] * (G[i,j] * np.sin(del1[i] - del1[j]) - B[i,j] * np.cos(del1[i] - del1[j]))
                F[i + num_buses][j] += -V[i] * (G[i,j]* np.sin(del1[i] - del1[j]) - B[i,j] * np.cos(del1[i] - del1[j]))

                # Partial derivatives of Q_i w.r.t. V_i, θ_i
                F[i  ][i] += V[j] * (G[i,j] * np.sin(del1[i] - del1[j]) - B[i,j] * np.cos(del1[i] - del1[j]))
                F[i  ][j] += V[i] * (G[i,j] * np.sin(del1[i] - del1[j]) - B[i,j] * np.cos(del1[i] - del1[j]))
                F[i + num_buses ][i] += V[i] * (G[i,j] * np.cos(del1[i] - del1[j]) + B[i,j] * np.sin(del1[i] - del1[j]))
                F[i + num_buses ][j] += V[i] * (G[i,j] * np.cos(del1[i] - del1[j]) + B[i,j] * np.sin(del1[i] - del1[j]))

        # Gain matrix
        
        
    E_pred=E ;
        
    P_pred=P;    
    P_pred= F*P*np.transpose(F) +Q;
        
        
    K= P_pred* np.transpose(H) *(np.linalg.inv((H*P_pred*np.transpose(H) + R)));
     
        
    # print(K.shape);
    
    # print(r.shape);
    
    E= E_pred+ np.matmul(K,r);
        
    
    P=(np.eye(2*nbus-1)-K*H)*P_pred ;
        
#         Z= H*E;
        
        
        
        
    
    # while tol>1e-4:
        
#         Gm = np.transpose(H)*np.linalg.inv(Ri)*H

#         dE = np.linalg.inv(Gm)*(np.transpose(H)*np.linalg.inv(Ri)*r)
#         E=E+dE

    del1[1:] = E[0:nbus-1]
    V=E[nbus-1:]

#         iter=iter+1
#         tol=np.max(np.abs(dE))
# #         print(tol);

    # ++++++++++++++++++++++
    # Presenting the results
    # ===================
    # print('for time ', Pi[x][0])
    # print('The tolerance value is: ',tol)
    print('The iteration number is: ',x)

    
    for i1 in range(0,14):
        if(i1==6):
            continue
        y11=V[i1]
        y_g[i1].append(y11.item())
        diff=(df[f'Subsystem #1|CTLs|Vars|Vrms_{i1+1}'][x]/11)-y_g[i1][c1]
        y_error[i1].append(diff)
        y_actual[i1].append(df[f'Subsystem #1|CTLs|Vars|Vrms_{i1+1}'][x]/11)
        abs_val=abs(diff)
        abs_val*=100
        y_per_error[i1].append((abs_val))
    
    x_g.append(x)
    
    c1=c1+1

#     print(del1);
#     V= np.array(V);
#     V=np.transpose(V);
#     Y_V=np.vstack([Y_V,V]);
    
#     del1=np.array(del1);
#     del1=np.transpose(del1);
#     Y_D=np.vstack([Y_D,del1]);

    # ++++++++++++++++++++++
    # Presenting the results
    # ======================
      
for i2 in range(14):
    # plot.plot(x_g,y_g[i2],label=f'bus {i2}')
    if(i2==6):
        continue
    # print(y_actual[i2][200:])
    plot.plot(x_g,y_error[i2],label=f"error")
    ax=plot.gca()
    # ax.set_ylim(-0.001756675,-0.001756650)
    plot.title(f'error in bus{i2+1} using ekf')
    plot.xlabel('time')
    plot.ylabel('error')
    plot.show()
    plot.plot(x_g,y_per_error[i2],label=f"percentage error")
    plot.title(f'percentage error in bus{i2+1} using ekf')
    plot.xlabel('time')
    plot.ylabel('percentage error')
    plot.show()
    plot.plot(x_g,y_actual[i2],label=f"actual")
    plot.plot(x_g,y_g[i2],label=f"predicted")
    ax=plot.gca()
    # ax.set_ylim(0.50,1.50)
    plot.title(f'actual and predicted in bus{i2+1} using ekf')
    plot.xlabel('time')
    plot.ylabel('voltage magnitude')
    plot.legend()
    plot.show()
# Out:
# The iteration number is:  800
# The iteration number is:  801
# The iteration number is:  802
# The iteration number is:  803
# The iteration number is:  804
# The iteration number is:  805
# The iteration number is:  806
# The iteration number is:  807
# The iteration number is:  808
# The iteration number is:  809
# The iteration number is:  810
# The iteration number is:  811
# The iteration number is:  812
# The iteration number is:  813
# The iteration number is:  814
# The iteration number is:  815
# The iteration number is:  816
# The iteration number is:  817
# The iteration number is:  818
# The iteration number is:  819
# The iteration number is:  820
# The iteration number is:  821
# The iteration number is:  822
# The iteration number is:  823
# The iteration number is:  824
# The iteration number is:  825
# The iteration number is:  826
# The iteration number is:  827
# The iteration number is:  828
# The iteration number is:  829
# The iteration number is:  830
# The iteration number is:  831
# The iteration number is:  832
# The iteration number is:  833
# The iteration number is:  834
# The iteration number is:  835
# The iteration number is:  836
# The iteration number is:  837
# The iteration number is:  838
# The iteration number is:  839
# The iteration number is:  840
# The iteration number is:  841
# The iteration number is:  842
# The iteration number is:  843
# The iteration number is:  844
# The iteration number is:  845
# The iteration number is:  846
# The iteration number is:  847
# The iteration number is:  848
# The iteration number is:  849
# The iteration number is:  850
# The iteration number is:  851
# The iteration number is:  852
# The iteration number is:  853
# The iteration number is:  854
# The iteration number is:  855
# The iteration number is:  856
# The iteration number is:  857
# The iteration number is:  858
# The iteration number is:  859
# The iteration number is:  860
# The iteration number is:  861
# The iteration number is:  862
# The iteration number is:  863
# The iteration number is:  864
# The iteration number is:  865
# The iteration number is:  866
# The iteration number is:  867
# The iteration number is:  868
# The iteration number is:  869
# The iteration number is:  870
# The iteration number is:  871
# The iteration number is:  872
# The iteration number is:  873
# The iteration number is:  874
# The iteration number is:  875
# The iteration number is:  876
# The iteration number is:  877
# The iteration number is:  878
# The iteration number is:  879
# The iteration number is:  880
# The iteration number is:  881
# The iteration number is:  882
# The iteration number is:  883
# The iteration number is:  884
# The iteration number is:  885
# The iteration number is:  886
# The iteration number is:  887
# The iteration number is:  888
# The iteration number is:  889
# The iteration number is:  890
# The iteration number is:  891
# The iteration number is:  892
# The iteration number is:  893
# The iteration number is:  894
# The iteration number is:  895
# The iteration number is:  896
# The iteration number is:  897
# The iteration number is:  898
# The iteration number is:  899
# The iteration number is:  900
# The iteration number is:  901
# The iteration number is:  902
# The iteration number is:  903
# The iteration number is:  904
# The iteration number is:  905
# The iteration number is:  906
# The iteration number is:  907
# The iteration number is:  908
# The iteration number is:  909
# The iteration number is:  910
# The iteration number is:  911
# The iteration number is:  912
# The iteration number is:  913
# The iteration number is:  914
# The iteration number is:  915
# The iteration number is:  916
# The iteration number is:  917
# The iteration number is:  918
# The iteration number is:  919
# The iteration number is:  920
# The iteration number is:  921
# The iteration number is:  922
# The iteration number is:  923
# The iteration number is:  924
# The iteration number is:  925
# The iteration number is:  926
# The iteration number is:  927
# The iteration number is:  928
# The iteration number is:  929
# The iteration number is:  930
# The iteration number is:  931
# The iteration number is:  932
# The iteration number is:  933
# The iteration number is:  934
# The iteration number is:  935
# The iteration number is:  936
# The iteration number is:  937
# The iteration number is:  938
# The iteration number is:  939
# The iteration number is:  940
# The iteration number is:  941
# The iteration number is:  942
# The iteration number is:  943
# The iteration number is:  944
# The iteration number is:  945
# The iteration number is:  946
# The iteration number is:  947
# The iteration number is:  948
# The iteration number is:  949
# The iteration number is:  950
# The iteration number is:  951
# The iteration number is:  952
# The iteration number is:  953
# The iteration number is:  954
# The iteration number is:  955
# The iteration number is:  956
# The iteration number is:  957
# The iteration number is:  958
# The iteration number is:  959
# The iteration number is:  960
# The iteration number is:  961
# The iteration number is:  962
# The iteration number is:  963
# The iteration number is:  964
# The iteration number is:  965
# The iteration number is:  966
# The iteration number is:  967
# The iteration number is:  968
# The iteration number is:  969
# The iteration number is:  970
# The iteration number is:  971
# The iteration number is:  972
# The iteration number is:  973
# The iteration number is:  974
# The iteration number is:  975
# The iteration number is:  976
# The iteration number is:  977
# The iteration number is:  978
# The iteration number is:  979
# The iteration number is:  980
# The iteration number is:  981
# The iteration number is:  982
# The iteration number is:  983
# The iteration number is:  984
# The iteration number is:  985
# The iteration number is:  986
# The iteration number is:  987
# The iteration number is:  988
# The iteration number is:  989
# The iteration number is:  990
# The iteration number is:  991
# The iteration number is:  992
# The iteration number is:  993
# The iteration number is:  994
# The iteration number is:  995
# The iteration number is:  996
# The iteration number is:  997
# The iteration number is:  998
# The iteration number is:  999
# The iteration number is:  1000
# The iteration number is:  1001
# The iteration number is:  1002
# The iteration number is:  1003
# The iteration number is:  1004
# The iteration number is:  1005
# The iteration number is:  1006
# The iteration number is:  1007
# The iteration number is:  1008
# The iteration number is:  1009
# The iteration number is:  1010
# The iteration number is:  1011
# The iteration number is:  1012
# The iteration number is:  1013
# The iteration number is:  1014
# The iteration number is:  1015
# The iteration number is:  1016
# The iteration number is:  1017
# The iteration number is:  1018
# The iteration number is:  1019
# The iteration number is:  1020
# The iteration number is:  1021
# The iteration number is:  1022
# The iteration number is:  1023
# The iteration number is:  1024
# The iteration number is:  1025
# The iteration number is:  1026
# The iteration number is:  1027
# The iteration number is:  1028
# The iteration number is:  1029
# The iteration number is:  1030
# The iteration number is:  1031
# The iteration number is:  1032
# The iteration number is:  1033
# The iteration number is:  1034
# The iteration number is:  1035
# The iteration number is:  1036
# The iteration number is:  1037
# The iteration number is:  1038
# The iteration number is:  1039
# The iteration number is:  1040
# The iteration number is:  1041
# The iteration number is:  1042
# The iteration number is:  1043
# The iteration number is:  1044
# The iteration number is:  1045
# The iteration number is:  1046
# The iteration number is:  1047
# The iteration number is:  1048
# The iteration number is:  1049
# The iteration number is:  1050
# The iteration number is:  1051
# The iteration number is:  1052
# The iteration number is:  1053
# The iteration number is:  1054
# The iteration number is:  1055
# The iteration number is:  1056
# The iteration number is:  1057
# The iteration number is:  1058
# The iteration number is:  1059
# The iteration number is:  1060
# The iteration number is:  1061
# The iteration number is:  1062
# The iteration number is:  1063
# The iteration number is:  1064
# The iteration number is:  1065
# The iteration number is:  1066
# The iteration number is:  1067
# The iteration number is:  1068
# The iteration number is:  1069
# The iteration number is:  1070
# The iteration number is:  1071
# The iteration number is:  1072
# The iteration number is:  1073
# The iteration number is:  1074
# The iteration number is:  1075
# The iteration number is:  1076
# The iteration number is:  1077
# The iteration number is:  1078
# The iteration number is:  1079
# The iteration number is:  1080
# The iteration number is:  1081
# The iteration number is:  1082
# The iteration number is:  1083
# The iteration number is:  1084
# The iteration number is:  1085
# The iteration number is:  1086
# The iteration number is:  1087
# The iteration number is:  1088
# The iteration number is:  1089
# The iteration number is:  1090
# The iteration number is:  1091
# The iteration number is:  1092
# The iteration number is:  1093
# The iteration number is:  1094
# The iteration number is:  1095
# The iteration number is:  1096
# The iteration number is:  1097
# The iteration number is:  1098
# The iteration number is:  1099
# The iteration number is:  1100
# The iteration number is:  1101
# The iteration number is:  1102
# The iteration number is:  1103
# The iteration number is:  1104
# The iteration number is:  1105
# The iteration number is:  1106
# The iteration number is:  1107
# The iteration number is:  1108
# The iteration number is:  1109
# The iteration number is:  1110
# The iteration number is:  1111
# The iteration number is:  1112
# The iteration number is:  1113
# The iteration number is:  1114
# The iteration number is:  1115
# The iteration number is:  1116
# The iteration number is:  1117
# The iteration number is:  1118
# The iteration number is:  1119
# The iteration number is:  1120
# The iteration number is:  1121
# The iteration number is:  1122
# The iteration number is:  1123
# The iteration number is:  1124
# The iteration number is:  1125
# The iteration number is:  1126
# The iteration number is:  1127
# The iteration number is:  1128
# The iteration number is:  1129
# The iteration number is:  1130
# The iteration number is:  1131
# The iteration number is:  1132
# The iteration number is:  1133
# The iteration number is:  1134
# The iteration number is:  1135
# The iteration number is:  1136
# The iteration number is:  1137
# The iteration number is:  1138
# The iteration number is:  1139
# The iteration number is:  1140
# The iteration number is:  1141
# The iteration number is:  1142
# The iteration number is:  1143
# The iteration number is:  1144
# The iteration number is:  1145
# The iteration number is:  1146
# The iteration number is:  1147
# The iteration number is:  1148
# The iteration number is:  1149
# The iteration number is:  1150
# The iteration number is:  1151
# The iteration number is:  1152
# The iteration number is:  1153
# The iteration number is:  1154
# The iteration number is:  1155
# The iteration number is:  1156
# The iteration number is:  1157
# The iteration number is:  1158
# The iteration number is:  1159
# The iteration number is:  1160
# The iteration number is:  1161
# The iteration number is:  1162
# The iteration number is:  1163
# The iteration number is:  1164
# The iteration number is:  1165
# The iteration number is:  1166
# The iteration number is:  1167
# The iteration number is:  1168
# The iteration number is:  1169
# The iteration number is:  1170
# The iteration number is:  1171
# The iteration number is:  1172
# The iteration number is:  1173
# The iteration number is:  1174
# The iteration number is:  1175
# The iteration number is:  1176
# The iteration number is:  1177
# The iteration number is:  1178
# The iteration number is:  1179
# The iteration number is:  1180
# The iteration number is:  1181
# The iteration number is:  1182
# The iteration number is:  1183
# The iteration number is:  1184
# The iteration number is:  1185
# The iteration number is:  1186
# The iteration number is:  1187
# The iteration number is:  1188
# The iteration number is:  1189
# The iteration number is:  1190
# The iteration number is:  1191
# The iteration number is:  1192
# The iteration number is:  1193
# The iteration number is:  1194
# The iteration number is:  1195
# The iteration number is:  1196
# The iteration number is:  1197
# The iteration number is:  1198
# The iteration number is:  1199
# The iteration number is:  1200
# The iteration number is:  1201
# The iteration number is:  1202
# The iteration number is:  1203
# The iteration number is:  1204
# The iteration number is:  1205
# The iteration number is:  1206
# The iteration number is:  1207
# The iteration number is:  1208
# The iteration number is:  1209
# The iteration number is:  1210
# The iteration number is:  1211
# The iteration number is:  1212
# The iteration number is:  1213
# The iteration number is:  1214
# The iteration number is:  1215
# The iteration number is:  1216
# The iteration number is:  1217
# The iteration number is:  1218
# The iteration number is:  1219
# The iteration number is:  1220
# The iteration number is:  1221
# The iteration number is:  1222
# The iteration number is:  1223
# The iteration number is:  1224
# The iteration number is:  1225
# The iteration number is:  1226
# The iteration number is:  1227
# The iteration number is:  1228
# The iteration number is:  1229
# The iteration number is:  1230
# The iteration number is:  1231
# The iteration number is:  1232
# The iteration number is:  1233
# The iteration number is:  1234
# The iteration number is:  1235
# The iteration number is:  1236
# The iteration number is:  1237
# The iteration number is:  1238
# The iteration number is:  1239
# The iteration number is:  1240
# The iteration number is:  1241
# The iteration number is:  1242
# The iteration number is:  1243
# The iteration number is:  1244
# The iteration number is:  1245
# The iteration number is:  1246
# The iteration number is:  1247
# The iteration number is:  1248
# The iteration number is:  1249
# The iteration number is:  1250
# The iteration number is:  1251
# The iteration number is:  1252
# The iteration number is:  1253
# The iteration number is:  1254
# The iteration number is:  1255
# The iteration number is:  1256
# The iteration number is:  1257
# The iteration number is:  1258
# The iteration number is:  1259
# The iteration number is:  1260
# The iteration number is:  1261
# The iteration number is:  1262
# The iteration number is:  1263
# The iteration number is:  1264
# The iteration number is:  1265
# The iteration number is:  1266
# The iteration number is:  1267
# The iteration number is:  1268
# The iteration number is:  1269
# The iteration number is:  1270
# The iteration number is:  1271
# The iteration number is:  1272
# The iteration number is:  1273
# The iteration number is:  1274
# The iteration number is:  1275
# The iteration number is:  1276
# The iteration number is:  1277
# The iteration number is:  1278
# The iteration number is:  1279
# The iteration number is:  1280
# The iteration number is:  1281
# The iteration number is:  1282
# The iteration number is:  1283
# The iteration number is:  1284
# The iteration number is:  1285
# The iteration number is:  1286
# The iteration number is:  1287
# The iteration number is:  1288
# The iteration number is:  1289
# The iteration number is:  1290
# The iteration number is:  1291
# The iteration number is:  1292
# The iteration number is:  1293
# The iteration number is:  1294
# The iteration number is:  1295
# The iteration number is:  1296
# The iteration number is:  1297
# The iteration number is:  1298
# The iteration number is:  1299
# The iteration number is:  1300
# The iteration number is:  1301
# The iteration number is:  1302
# The iteration number is:  1303
# The iteration number is:  1304
# The iteration number is:  1305
# The iteration number is:  1306
# The iteration number is:  1307
# The iteration number is:  1308
# The iteration number is:  1309
# The iteration number is:  1310
# The iteration number is:  1311
# The iteration number is:  1312
# The iteration number is:  1313
# The iteration number is:  1314
# The iteration number is:  1315
# The iteration number is:  1316
# The iteration number is:  1317
# The iteration number is:  1318
# The iteration number is:  1319
# The iteration number is:  1320
# The iteration number is:  1321
# The iteration number is:  1322
# The iteration number is:  1323
# The iteration number is:  1324
# The iteration number is:  1325
# The iteration number is:  1326
# The iteration number is:  1327
# The iteration number is:  1328
# The iteration number is:  1329
# The iteration number is:  1330
# The iteration number is:  1331
# The iteration number is:  1332
# The iteration number is:  1333
# The iteration number is:  1334
# The iteration number is:  1335
# The iteration number is:  1336
# The iteration number is:  1337
# The iteration number is:  1338
# The iteration number is:  1339
# The iteration number is:  1340
# The iteration number is:  1341
# The iteration number is:  1342
# The iteration number is:  1343
# The iteration number is:  1344
# The iteration number is:  1345
# The iteration number is:  1346
# The iteration number is:  1347
# The iteration number is:  1348
# The iteration number is:  1349
# The iteration number is:  1350
# The iteration number is:  1351
# The iteration number is:  1352
# The iteration number is:  1353
# The iteration number is:  1354
# The iteration number is:  1355
# The iteration number is:  1356
# The iteration number is:  1357
# The iteration number is:  1358
# The iteration number is:  1359
# The iteration number is:  1360
# The iteration number is:  1361
# The iteration number is:  1362
# The iteration number is:  1363
# The iteration number is:  1364
# The iteration number is:  1365
# The iteration number is:  1366
# The iteration number is:  1367
# The iteration number is:  1368
# The iteration number is:  1369
# The iteration number is:  1370
# The iteration number is:  1371
# The iteration number is:  1372
# The iteration number is:  1373
# The iteration number is:  1374
# The iteration number is:  1375
# The iteration number is:  1376
# The iteration number is:  1377
# The iteration number is:  1378
# The iteration number is:  1379
# The iteration number is:  1380
# The iteration number is:  1381
# The iteration number is:  1382
# The iteration number is:  1383
# The iteration number is:  1384
# The iteration number is:  1385
# The iteration number is:  1386
# The iteration number is:  1387
# The iteration number is:  1388
# The iteration number is:  1389
# The iteration number is:  1390
# The iteration number is:  1391
# The iteration number is:  1392
# The iteration number is:  1393
# The iteration number is:  1394
# The iteration number is:  1395
# The iteration number is:  1396
# The iteration number is:  1397
# The iteration number is:  1398
# The iteration number is:  1399
# The iteration number is:  1400
# The iteration number is:  1401
# The iteration number is:  1402
# The iteration number is:  1403
# The iteration number is:  1404
# The iteration number is:  1405
# The iteration number is:  1406
# The iteration number is:  1407
# The iteration number is:  1408
# The iteration number is:  1409
# The iteration number is:  1410
# The iteration number is:  1411
# The iteration number is:  1412
# The iteration number is:  1413
# The iteration number is:  1414
# The iteration number is:  1415
# The iteration number is:  1416
# The iteration number is:  1417
# The iteration number is:  1418
# The iteration number is:  1419
# The iteration number is:  1420
# The iteration number is:  1421
# The iteration number is:  1422
# The iteration number is:  1423
# The iteration number is:  1424
# The iteration number is:  1425
# The iteration number is:  1426
# The iteration number is:  1427
# The iteration number is:  1428
# The iteration number is:  1429
# The iteration number is:  1430
# The iteration number is:  1431
# The iteration number is:  1432
# The iteration number is:  1433
# The iteration number is:  1434
# The iteration number is:  1435
# The iteration number is:  1436
# The iteration number is:  1437
# The iteration number is:  1438
# The iteration number is:  1439
# The iteration number is:  1440
# The iteration number is:  1441
# The iteration number is:  1442
# The iteration number is:  1443
# The iteration number is:  1444
# The iteration number is:  1445
# The iteration number is:  1446
# The iteration number is:  1447
# The iteration number is:  1448
# The iteration number is:  1449
# The iteration number is:  1450
# The iteration number is:  1451
# The iteration number is:  1452
# The iteration number is:  1453
# The iteration number is:  1454
# The iteration number is:  1455
# The iteration number is:  1456
# The iteration number is:  1457
# The iteration number is:  1458
# The iteration number is:  1459
# The iteration number is:  1460
# The iteration number is:  1461
# The iteration number is:  1462
# The iteration number is:  1463
# The iteration number is:  1464
# The iteration number is:  1465
# The iteration number is:  1466
# The iteration number is:  1467
# The iteration number is:  1468
# The iteration number is:  1469
# The iteration number is:  1470
# The iteration number is:  1471
# The iteration number is:  1472
# The iteration number is:  1473
# The iteration number is:  1474
# The iteration number is:  1475
# The iteration number is:  1476
# The iteration number is:  1477
# The iteration number is:  1478
# The iteration number is:  1479
# The iteration number is:  1480
# The iteration number is:  1481
# The iteration number is:  1482
# The iteration number is:  1483
# The iteration number is:  1484
# The iteration number is:  1485
# The iteration number is:  1486
# The iteration number is:  1487
# The iteration number is:  1488
# The iteration number is:  1489
# The iteration number is:  1490
# The iteration number is:  1491
# The iteration number is:  1492
# The iteration number is:  1493
# The iteration number is:  1494
# The iteration number is:  1495
# The iteration number is:  1496
# The iteration number is:  1497
# The iteration number is:  1498
# The iteration number is:  1499
